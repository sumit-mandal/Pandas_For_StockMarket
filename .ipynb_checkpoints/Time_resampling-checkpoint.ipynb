# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('walmart_stock.csv')

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 1  2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2  2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 3  2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 4  2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Volume     1258 non-null   int64
#  6   Adj Close  1258 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %%
# since  our date is string we need to convert in into datetime-object

# %%
df['Date1'] = pd.to_datetime(df['Date'])

# %%
type(df['Date1'])
# Out:
# pandas.core.series.Series

# %%
df.info
# Out:
# <bound method DataFrame.info of             Date       Open       High        Low      Close    Volume  \
# 0     2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800
# 1     2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300
# 2     2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200
# 3     2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400
# 4     2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300
# ...          ...        ...        ...        ...        ...       ...
# 1253  2016-12-23  69.430000  69.750000  69.360001  69.540001   4803900
# 1254  2016-12-27  69.300003  69.820000  69.250000  69.699997   4435700
# 1255  2016-12-28  69.940002  70.000000  69.260002  69.309998   4875700
# 1256  2016-12-29  69.209999  69.519997  69.120003  69.260002   4298400
# 1257  2016-12-30  69.120003  69.430000  68.830002  69.120003   6889500
#
#       Adj Close      Date1
# 0     52.619235 2012-01-03
# 1     52.078475 2012-01-04
# ...

# %% [markdown]
# # Alternative to above process

# %%
df = pd.read_csv('walmart_stock.csv',index_col='Date',parse_dates = True)

# %%
df.index
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                '2016-12-29', '2016-12-30'],
#               dtype='datetime64[ns]', name='Date', length=1258, freq=None)

# %% [markdown]
# ## `Here our String directly got converted into datetime datatype.`
#
# ### `WE used index_col to determine which column needs to be converted into date time format. And parse_date=True converts it into datetype datatype`

# %%
# ## Time resampling
# df = pd.read_csv('walmart_stock.csv')
# df['Date1'] = pd.to_datetime(df['Date'])

# %%
df.resample(rule='A').mean()
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2012-12-31  67.158680  67.602120  66.786520  67.215120  9.239015e+06
# 2013-12-31  75.264048  75.729405  74.843055  75.320516  6.951496e+06
# 2014-12-31  77.274524  77.740040  76.864405  77.327381  6.515612e+06
# 2015-12-31  72.569405  73.064167  72.034802  72.491111  9.040769e+06
# 2016-12-31  69.481349  70.019643  69.023492  69.547063  9.371645e+06
#
#             Adj Close
# Date
# 2012-12-31  59.389349
# 2013-12-31  68.147179
# 2014-12-31  71.709712
# 2015-12-31  68.831426
# 2016-12-31  68.054229

# %%
#quaterly
df.resample(rule='Q').mean()
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 2012-03-31  60.462903  60.807258  60.160484  60.519516  8.850221e+06
# 2012-06-30  62.888889  63.400159  62.592222  63.057143  1.155795e+07
# 2012-09-30  73.081587  73.549682  72.717619  73.174921  7.871587e+06
# 2012-12-31  72.174678  72.623226  71.647741  72.079839  8.660958e+06
# 2013-03-31  70.898834  71.393000  70.552666  71.026000  8.482003e+06
# 2013-06-30  76.873906  77.417813  76.413281  76.885781  7.656086e+06
# 2013-09-30  75.637969  76.030469  75.213594  75.629063  5.796625e+06
# 2013-12-31  77.372656  77.805313  76.924531  77.472813  5.966927e+06
# 2014-03-31  75.339344  75.802787  74.863278  75.337213  7.050402e+06
# 2014-06-30  77.036508  77.391111  76.689524  77.066508  6.048765e+06
# 2014-09-30  75.674843  76.062501  75.375938  75.748593  5.550031e+06
# 2014-12-31  80.952969  81.607500  80.432344  81.059844  7.431025e+06
# ...

# %%
df['Close'].resample('M').mean().plot(kind='bar',figsize=(16,6)) #resample('M') means month
# Out:
# <AxesSubplot:xlabel='Date'>
